# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np

train_loss_6M_dim_6 = np.load("hidden_dim_6_val_loss_values.npy")
train_loss_6M_dim_15 = np.load("hidden_dim_15_val_loss_values.npy")
train_loss_6M_dim_32 = np.load("hidden_dim_30_val_loss_values.npy")
train_loss_6M_dim_63 = np.load("hidden_dim_63_val_loss_values.npy")
train_loss_6M_dim_126 = np.load("hidden_dim_126_val_loss_values.npy")
train_loss_6M_dim_255 = np.load("6M_hidden_dim_255_val_loss_values.npy")
train_loss_6M = np.load("6M_16bit_batchsize16_val_loss_values.npy")
train_loss_6M_dim_1024 = np.load("6M_hidden_dim_1024_16bit.npy")


plt.figure(figsize=(12, 8)) 
plt.plot(train_loss_6M_dim_6, 'yo', label='hid_dim_6')
plt.plot(train_loss_6M_dim_15, 'o', color='orange', label='hid_dim_15')
plt.plot(train_loss_6M_dim_32, 'co', label='hid_dim_32')
plt.plot(train_loss_6M_dim_63, 'go', label='hid_dim_63')
plt.plot(train_loss_6M_dim_126, 'bo', label='hid_dim_126')
plt.plot(train_loss_6M_dim_255, 'mo', label='hid_dim_255')
plt.plot(train_loss_6M , 'ko', label='hid_dim_576')
plt.plot(train_loss_6M_dim_1024, 'ro', label='hid_dim_1024')
plt.xlabel('Epochs',fontsize=24)
plt.ylabel('Cross-Entropy',fontsize=24)
plt.title('Training loss with various hidden dimensions in the GPT model',fontsize=24)
plt.legend(fontsize=20, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tick_params(axis='both', which='major', labelsize=24)
plt.show()

# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np

train_loss_6M_L_1 = np.load("numbe_layers_1_val_loss_values.npy")
train_loss_6M_L_2 = np.load("numbe_layers_2_val_loss_values.npy")
train_loss_6M_L_4 = np.load("6M_numbe_layers_4_val_loss_values.npy")
train_loss_6M_L_8 = np.load("6M_16bit_batchsize16_val_loss_values.npy")
train_loss_6M_L_16 = np.load("6M_numbe_layers_16_val_loss_values.npy")


plt.figure(figsize=(12, 8))  
plt.plot(train_loss_6M_L_1, 'go', label='num_layers_1')
plt.plot(train_loss_6M_L_2, 'bo', label='num_layers_2')
plt.plot(train_loss_6M_L_4, 'mo', label='num_layers_4')
plt.plot(train_loss_6M_L_8 , 'ko', label='num_layers_8')
plt.plot(train_loss_6M_L_16, 'ro', label='num_layers_16')

plt.xlabel('Epochs',fontsize=24)
plt.ylabel('Cross-Entropy',fontsize=24)
plt.title('Training loss with various number of layers in the GPT model',fontsize=24)
plt.legend(fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=24)
plt.show()

# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np



train_loss_6M_head_1 = np.load("6M_number_heads_1val_loss_values.npy")
train_loss_6M_head_2 = np.load("6M_number_heads_2_val_loss_values.npy")
train_loss_6M_head_4 = np.load("6M_16bit_batchsize16_val_loss_values.npy")
train_loss_6M_head_8 = np.load("head_8_val_loss_values.npy")

plt.figure(figsize=(12, 8))  
plt.plot(train_loss_6M_head_1 , 'go', label='num_heads_1')
plt.plot(train_loss_6M_head_2, 'bo', label='num_heads_2')
plt.plot(train_loss_6M_head_4 , 'ko', label='num_heads_4')
plt.plot(train_loss_6M_head_8, 'ro', label='num_heads_8')

plt.xlabel('Epochs',fontsize=24)
plt.ylabel('Cross-Entropy',fontsize=24)
plt.title('Training loss with various number of heads in the GPT model',fontsize=24)
plt.legend(fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=24)
plt.show()
