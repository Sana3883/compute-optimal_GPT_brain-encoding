# %%
import numpy as np
from nilearn.maskers import NiftiLabelsMasker
from nilearn.datasets import fetch_neurovault_ids
from nilearn.plotting.cm import _cmap_d as nilearn_cmaps


from neuromaps import transforms 
from surfplot import Plot

from neuromaps.transforms import mni152_to_fslr
from neuromaps.datasets import fetch_fslr
from surfplot import Plot
from nilearn.plotting.cm import _cmap_d as nilearn_cmaps

from neuromaps.datasets import fetch_fslr
from nilearn.regions import signals_to_img_labels
from nilearn import regions
import surfplot as spl
from surfplot.utils import threshold
from nilearn.input_data import NiftiMasker
from nilearn.plotting  import view_img
from nilearn import plotting


from nilearn.image import math_img
# Out:
# /home/user/.local/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()
# /home/user/.local/lib/python3.7/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
def nilearn_create_surface_map_from_parcellated_signal(data, parcellation, zoom=None, shape='inflated'):
    #transform data from parcellation to volumetric (niimg)
    data_nii = regions.signals_to_img_labels(data,parcellation)
    print(data_nii.shape)
    
    plotting.plot_img_on_surf(data_nii,
                          surf_mesh='fsaverage',
                          views=['lateral', 'medial'],
                          hemispheres=['left', 'right'],
                          colorbar=True, inflate=True)
    plotting.show()

# %% [markdown]
# # sub-01

# %% [markdown]
# ## number of frames:  10k

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub1/Sub1_10k_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (1095,)
# Max_value: 0.39515082264617424
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  100k

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub1/Sub1_100k_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.5867867479292131
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  1M

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub1/Sub1_1M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095)) 
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.6143949201058635
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  6M

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub1/Sub1_6M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095)) 
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.6199158061236628
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# # Sub-02

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub2/Sub2_10k_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.33111054955522834
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub2/Sub2_100K_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.3551837013123028
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub2/Sub2_1M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.389123711629462
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub2/Sub2_6M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.36382878827835663
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# # Sub-04

# %% [markdown]
# ## number of frames:  10k

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub4/Sub4_10k_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.46403582028316387
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  100k

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub4/Sub4_100K_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))    
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.6078130129226957
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  1M

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub4/Sub4_1M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))    
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.6547322864906592
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  6M

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/Sub4/Sub4_6M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))    
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.673617377378472
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# #  Sub-06

# %% [markdown]
# ## number of frames:  10k

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub6/Sub6_10k_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.11211133557321984
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  100k

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub6/Sub6_100k_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.47939121240206906
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  1M

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub6/Sub6_1M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.5273618031151357
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## number of frames:  6M

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/sub6/Sub6_6M_attn_stack.attn_nets.4.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.5677299635181967
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)
