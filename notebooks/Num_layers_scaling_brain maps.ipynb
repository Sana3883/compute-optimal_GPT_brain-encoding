# %%
import numpy as np
from nilearn.maskers import NiftiLabelsMasker
from nilearn.datasets import fetch_neurovault_ids
from nilearn.plotting.cm import _cmap_d as nilearn_cmaps


from neuromaps import transforms 
from surfplot import Plot
 
from neuromaps.transforms import mni152_to_fslr
from neuromaps.datasets import fetch_fslr
from surfplot import Plot
from nilearn.plotting.cm import _cmap_d as nilearn_cmaps

from neuromaps.datasets import fetch_fslr
from nilearn.regions import signals_to_img_labels
from nilearn import regions
import surfplot as spl
from surfplot.utils import threshold
from nilearn.input_data import NiftiMasker
from nilearn.plotting  import view_img
from nilearn import plotting


from nilearn.image import math_img
# Out:
# /home/user/.local/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()
# /home/user/.local/lib/python3.7/site-packages/nilearn/input_data/__init__.py:23: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
def nilearn_create_surface_map_from_parcellated_signal(data, parcellation, vmax_value, zoom=None, shape='inflated'):
    # Transform data from parcellation to volumetric (niimg)
    data_nii = regions.signals_to_img_labels(data, parcellation)
    print(data_nii.shape)
    
    plotting.plot_img_on_surf(data_nii,
                              surf_mesh='fsaverage',
                              views=['lateral', 'medial'],
                              hemispheres=['left', 'right'],
                              colorbar=True,
                              inflate=True,
                              vmax=vmax_value)
    plotting.show()

# %% [markdown]
# # number of layers: 1

# %% [markdown]
# ## sub-01

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_1/sub1/Sub1_6M_attn_stack.attn_nets.0.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.5089708847971952
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub-02

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_1/sub2/6M_attn_stack.attn_nets.0.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.2944752046509543
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub-04

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_1/sub4/6M_attn_stack.attn_nets.0.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.5834490591086352
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub-06

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_1/sub6/6M_attn_stack.attn_nets.0.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.41339417705836
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# # Number of layers: 2

# %% [markdown]
# ## Sub-01

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_2/sub1/Sub1_6M_attn_stack.attn_nets.1.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.5053580659244976
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## Sub-02

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_2/sub2/6M_attn_stack.attn_nets.1.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.3329409771603241
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## Sub-04

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_2/sub4/6M_attn_stack.attn_nets.1.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.56878323912993
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## Sub-06

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_2/sub6/6M_attn_stack.attn_nets.1.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.4137930973778447
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# # Number of layers: 4

# %% [markdown]
# ## sub1

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_4/sub1/Sub1_6M_attn_stack.attn_nets.3.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.46553577618814795
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub2

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_4/sub2/6M_attn_stack.attn_nets.3.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.32450736813679765
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub4

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_4/sub4/6M_attn_stack.attn_nets.3.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.551359074098573
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub6

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_4/sub6/6M_attn_stack.attn_nets.3.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.38873648102032937
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# #  Number of layers: 8

# %% [markdown]
# ## sub1

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_8/sub1/Sub1_6M_attn_stack.attn_nets.7.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.4921462272043961
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub2

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_8/sub2/6M_attn_stack.attn_nets.7.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.2869980301166854
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub4

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_8/sub4/6M_attn_stack.attn_nets.7.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.5395857678707714
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)

# %% [markdown]
# ## sub6

# %%
import numpy as np
#masker='Data_last/MIST_444.nii.gz'
masker='MIST_ATOM.nii.gz'
Ridge_correlations = np.load('VideoGPT/number_hidden_layers/num_8/sub6/6M_attn_stack.attn_nets.7.post_fc_dp_correlations.npy', allow_pickle=True)
print(Ridge_correlations.shape)
Ridge_correlations=Ridge_correlations.reshape((1,1095))
vmax_value=np. max(Ridge_correlations)
print("Max_value:",np. max(Ridge_correlations))
nilearn_create_surface_map_from_parcellated_signal(Ridge_correlations, masker,vmax_value, zoom=None, shape='inflated')
# Out:
# (1095,)
# Max_value: 0.3973553320534158
# /home/user/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Applying "mask_img" before signal extraction may result in empty region signals in the output. These are currently kept. Starting from version 0.13, the default behavior will be changed to remove them by setting "keep_masked_labels=False". "keep_masked_labels" parameter will be removed in version 0.15.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (53, 64, 52, 1)
